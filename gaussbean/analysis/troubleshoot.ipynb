# %%
import calc
import prettier
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

path = 'Rough_Scan/3.tif'
im = np.array(Image.open(path))

# %%
x,y = calc.find_centroid(imgar=prettier.thru_median(path, 5, 8))

# %%
plt.imshow(prettier.thru_median(path, 5, 3))
plt.plot(x, y, '.', color='red')

# %%
plt.imshow(prettier.crop_image(x, y, 100, 150, imgar=prettier.thru_median(path, 5, 3)))
